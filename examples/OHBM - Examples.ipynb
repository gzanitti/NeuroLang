# %%
from neurolang.datalog.ontologies_parser import OntologiesParser
from neurolang.datalog.ontologies_rewriter import OntologyRewriter

from neurolang.datalog.constraints_representation import DatalogConstraintsProgram
from neurolang.expression_walker import ExpressionBasicEvaluator

from neurolang import frontend as fe

class Datalog(DatalogConstraintsProgram, ExpressionBasicEvaluator):
    pass

paths = ['./neurofma_fma3.0.owl']
namespaces = ['http://sig.biostr.washington.edu/fma3.0']
onto = OntologiesParser(paths, namespaces)
dl = Datalog()
nl = fe.NeurolangDL()
datalog_program = onto.parse_ontology(nl.solver)

# %%
def get_destrieux_relations():
    return [
        ('l_g_and_s_frontomargin', 'Left frontomarginal gyrus'),
        ('l_g_and_s_occipital_inf', 'Left inferior occipital gyrus'),
        ('l_g_and_s_paracentral', 'Left paracentral lobule'),
        ('l_g_and_s_subcentral', 'Left subcentral gyrus'),
        (
            'l_g_and_s_transv_frontopol',
            'Left superior transverse frontopolar gyrus'
        ),
        ('l_g_and_s_cingul_ant', 'Left anterior cingulate gyrus'),
        (
            'l_g_and_s_cingul_mid_ant',
            'Left anterior middle cingulate gyrus'
        ),
        (
            'l_g_and_s_cingul_mid_post',
            'Left posterior middle cingulate gyrus'
        ),
        (
            'l_g_cingul_post_dorsal',
            'Dorsal segment of left posterior middle cingulate gyrus'
        ),
        (
            'l_g_cingul_post_ventral',
            'Ventral segment of left posterior middle cingulate gyrus'
        ),
        ('l_g_cuneus', 'Left cuneus'),
        (
            'l_g_front_inf_opercular',
            'Opercular part of left inferior frontal gyrus'
        ),
        (
            'l_g_front_inf_orbital',
            'Orbital part of left inferior frontal gyrus'
        ),
        (
            'l_g_front_inf_triangul',
            'Triangular part of left inferior frontal gyrus'
        ),
        ('l_g_front_middle', 'Left middle frontal gyrus'),
        ('l_g_front_sup', 'Left superior frontal gyrus'),
        ('l_g_ins_lg_and_s_cent_ins', 'Left central insular sulcus'),
        ('l_g_ins_lg_and_s_cent_ins', 'Left long insular gyrus'),
        ('l_g_insular_short', 'Short insular gyrus'),
        ('l_g_occipital_middleLeft', ' 	Left lateral occipital gyrus'),
        ('l_g_occipital_sup', 'Left superior occipital gyrus'),
        ('l_g_oc_temp_lat_fusifor', 'Left fusiform gyrus'),
        ('l_g_oc_temp_med_lingual', 'Left lingual gyrus'),
        ('l_g_oc_temp_med_parahip', 'Left parahippocampal gyrus'),
        ('l_g_orbital', 'Left orbital gyrus'),
        ('l_g_pariet_inf_angular', 'Left angular gyrus'),
        ('l_g_pariet_inf_supramar', 'Left supramarginal gyrus'),
        ('l_g_parietal_sup', 'Left superior parietal lobule'),
        ('l_g_postcentral', 'Left postcentral gyrus'),
        ('l_g_precentral', 'Left precentral gyrus'),
        ('l_g_precuneus', 'Left precuneus'),
        ('l_g_rectus', 'Left straight gyrus'),
        ('l_g_subcallosal', 'Left paraterminal gyrus'),
        ('l_g_temp_sup_g_t_transv', 'Left transverse temporal gyrus'),
        ('l_g_temp_sup_lateral', 'Left superior temporal gyrus'),
        ('l_g_temp_sup_plan_polar', 'Left superior temporal gyrus'),
        ('l_g_temp_sup_plan_tempo', 'Left superior temporal gyrus'),
        ('l_g_temporal_inf', 'Left inferior temporal gyrus'),
        ('l_g_temporal_middle', 'Left middle temporal gyrus'),
        (
            'l_lat_fis_ant_horizont',
            'Anterior horizontal limb of left lateral sulcus'
        ),
        (
            'l_lat_fis_ant_vertical',
            'Anterior ascending limb of left lateral sulcus'
        ),
        (
            'l_lat_fis_post',
            'Posterior ascending limb of left lateral sulcus'
        ),
        ('l_lat_fis_post', 'Left lateral sulcus'),
        ('l_pole_occipital', 'Left occipital pole'),
        ('l_pole_temporal', 'Left temporal pole'),
        ('l_s_calcarine', 'Left Calcarine sulcus'),
        ('l_s_central', 'Left central sulcus'),
        ('l_s_cingul_marginalis', 'Left marginal sulcus'),
        ('l_s_circular_insula_ant', 'Circular sulcus of left insula'),
        ('l_s_circular_insula_inf', 'Circular sulcus of left insula'),
        ('l_s_circular_insula_sup', 'Circular sulcus of left insula'),
        ('l_s_collat_transv_ant', 'Left collateral sulcus'),
        ('l_s_collat_transv_post', 'Left collateral sulcus'),
        ('l_s_front_inf', 'Left inferior frontal sulcus'),
        ('l_s_front_sup', 'Left superior frontal sulcus'),
        ('l_s_intrapariet_and_p_trans', 'Left intraparietal sulcus'),
        ('l_s_oc_middle_and_lunatus', 'Left lunate sulcus'),
        ('l_s_oc_sup_and_transversal', 'Left transverse occipital sulcus'),
        ('l_s_occipital_ant', 'Left anterior occipital sulcus'),
        ('l_s_oc_temp_lat', 'Left occipitotemporal sulcus'),
        ('l_s_oc_temp_med_and_lingual', 'Left intralingual sulcus'),
        ('l_s_orbital_lateral', 'Left orbital sulcus'),
        ('l_s_orbital_med_olfact', 'Left olfactory sulcus'),
        ('l_s_orbital_h_shaped', 'Left transverse orbital sulcus'),
        ('l_s_orbital_h_shaped', 'Left orbital sulcus'),
        ('l_s_parieto_occipital', 'Left parieto-occipital sulcus'),
        ('l_s_pericallosal', 'Left callosal sulcus'),
        ('l_s_postcentral', 'Left postcentral sulcus'),
        ('l_s_precentral_inf_part', 'Left precentral sulcus'),
        ('l_s_precentral_sup_part', 'Left precentral sulcus'),
        ('l_s_suborbital', 'Left fronto-orbital sulcus'),
        ('l_s_subparietal', 'Left subparietal sulcus'),
        ('l_s_temporal_inf', 'Left inferior temporal sulcus'),
        ('l_s_temporal_sup', 'Left superior temporal sulcus'),
        ('l_s_temporal_transverse', 'Left transverse temporal sulcus'),
        ('r_g_and_s_frontomargin', 'Right frontomarginal gyrus'),
        ('r_g_and_s_occipital_inf', 'Right inferior occipital gyrus'),
        ('r_g_and_s_paracentral', 'Right paracentral lobule'),
        ('r_g_and_s_subcentral', 'Right subcentral gyrus'),
        (
            'r_g_and_s_transv_frontopol',
            'Right superior transverse frontopolar gyrus'
        ),
        ('r_g_and_s_cingul_ant', 'Right anterior cingulate gyrus'),
        (
            'r_g_and_s_cingul_mid_ant',
            'Right anterior middle cingulate gyrus'
        ),
        (
            'r_g_and_s_cingul_mid_post',
            'Right posterior middle cingulate gyrus'
        ),
        (
            'r_g_cingul_post_dorsal',
            'Dorsal segment of right posterior middle cingulate gyrus'
        ),
        (
            'r_g_cingul_post_ventral',
            'Ventral segment of right posterior middle cingulate gyrus'
        ),
        ('r_g_cuneus', 'Right cuneus'),
        (
            'r_g_front_inf_opercular',
            'Opercular part of right inferior frontal gyrus'
        ),
        (
            'r_g_front_inf_orbital',
            'Orbital part of right inferior frontal gyrus'
        ),
        (
            'r_g_front_inf_triangul',
            'Triangular part of right inferior frontal gyrus'
        ),
        ('r_g_front_middle', 'Right middle frontal gyrus'),
        ('r_g_front_sup', 'Right superior frontal gyrus'),
        ('r_g_ins_lg_and_s_cent_ins', 'Right central insular sulcus'),
        ('r_g_ins_lg_and_s_cent_ins', 'Right long insular gyrus'),
        ('r_g_insular_short', 'Right short insular gyrus'),
        ('r_g_occipital_middle', 'Right lateral occipital gyrus'),
        ('r_g_occipital_sup', 'Right superior occipital gyrus'),
        ('r_g_oc_temp_lat_fusifor', 'Right fusiform gyrus'),
        ('r_g_oc_temp_med_lingual', 'Right lingual gyrus'),
        ('r_g_oc_temp_med_parahip', 'Right parahippocampal gyrus'),
        ('r_g_orbital', 'Right orbital gyrus'),
        ('r_g_pariet_inf_angular', 'Right angular gyrus'),
        ('r_g_pariet_inf_supramar', 'Right supramarginal gyrus'),
        ('r_g_parietal_sup', 'Right superior parietal lobule'),
        ('r_g_postcentral', 'Right postcentral gyrus'),
        ('r_g_precentral', 'Right precentral gyrus'),
        ('r_g_precuneus', 'Right precuneus'),
        ('r_g_rectus', 'Right straight gyrus'),
        ('r_g_subcallosal', 'Right paraterminal gyrus'),
        ('r_g_temp_sup_g_t_transv', 'Right transverse temporal gyrus'),
        ('r_g_temp_sup_lateral', 'Right superior temporal gyrus'),
        ('r_g_temp_sup_plan_polar', 'Right superior temporal gyrus'),
        ('r_g_temp_sup_plan_tempo', 'Right superior temporal gyrus'),
        ('r_g_temporal_inf', 'Right inferior temporal gyrus'),
        ('r_g_temporal_middle', 'Right middle temporal gyrus'),
        (
            'r_lat_fis_ant_horizont',
            'Anterior horizontal limb of right lateral sulcus'
        ),
        (
            'r_lat_fis_ant_vertical',
            'Anterior ascending limb of right lateral sulcus'
        ),
        ('r_lat_fis_post', 'Right lateral sulcus'),
        (
            'r_lat_fis_post',
            'Posterior ascending limb of right lateral sulcus'
        ),
        ('r_pole_occipital', 'Right occipital pole'),
        ('r_pole_temporal', 'Right temporal pole'),
        ('r_s_calcarine', 'Right Calcarine sulcus'),
        ('r_s_central', 'Right central sulcus'),
        ('r_s_cingul_marginalis', 'Right marginal sulcus'),
        ('r_s_circular_insula_ant', 'Circular sulcus of Right insula'),
        ('r_s_circular_insula_inf', 'Circular sulcus of Right insula'),
        ('r_s_circular_insula_sup', 'Circular sulcus of Right insula'),
        ('r_s_collat_transv_ant', 'Right collateral sulcus'),
        ('r_s_collat_transv_post', 'Right collateral sulcus'),
        ('r_s_front_inf', 'Right inferior frontal sulcus'),
        ('r_s_front_sup', 'Right superior frontal sulcus'),
        ('r_s_intrapariet_and_p_trans', 'Right intraparietal sulcus'),
        ('r_s_oc_middle_and_lunatus', 'Right lunate sulcus'),
        (
            'r_s_oc_sup_and_transversal',
            'Right transverse occipital sulcus'
        ),
        ('r_s_occipital_ant', 'Right anterior occipital sulcus'),
        ('r_s_oc_temp_lat', 'Right occipitotemporal sulcus'),
        ('r_s_oc_temp_med_and_lingual', 'Right intralingual sulcus'),
        ('r_s_orbital_lateral', 'Right orbital sulcus'),
        ('r_s_orbital_med_olfact', 'Right olfactory sulcus'),
        ('r_s_orbital_h_shaped', 'Right orbital sulcus'),
        ('r_s_orbital_h_shaped', 'Right transverse orbital sulcus'),
        ('r_s_parieto_occipital', 'Right parieto-occipital sulcus'),
        ('r_s_pericallosal', 'Right callosal sulcus'),
        ('r_s_postcentral', 'Right postcentral sulcus'),
        ('r_s_precentral_inf_part', 'Right precentral sulcus'),
        ('r_s_precentral_sup_part', 'Right precentral sulcus'),
        ('r_s_suborbital', 'Right fronto-orbital sulcus'),
        ('r_s_subparietal', 'Right subparietal sulcus'),
        ('r_s_temporal_inf', 'Right inferior temporal sulcus'),
        ('r_s_temporal_sup', 'Right superior temporal sulcus'),
        ('r_s_temporal_transverse', 'Right transverse temporal sulcus'),
    ]

# %%
from neurolang.logic import Implication
from nilearn import datasets
import nibabel as nib
from neurolang.frontend.query_resolution import RegionMixin
from neurolang.expressions import ExpressionBlock, Symbol, Constant
from neurolang.logic import Implication
from neurolang.regions import Region, region_union as region_union_
import typing 

relations_list = get_destrieux_relations()

S_ = Symbol
C_ = Constant

#relation_region = S_('relation_region')
#relation_name = S_('relation_name')

#r_name = tuple([relation_name(C_(destrieux), C_(fma)) for destrieux, fma in relations_list])

#destrieux_dataset = datasets.fetch_atlas_destrieux_2009()
#destrieux_map = nib.load(destrieux_dataset['maps'])

#destrieux = []
#for label_number, name in destrieux_dataset['labels']:
#    if label_number == 0:
#        continue
#    name = name.decode()
#    region = RegionMixin.create_region(
#        destrieux_map, label=label_number
#    )
#    if region is None:
#        continue
#    name = name.replace('-', '_').replace(' ', '_').lower()
#    destrieux.append((name, region))
#
#r_region = tuple([relation_region(C_(region), C_(name)) for name, region in destrieux])


relations_list = get_destrieux_relations()
nl.add_tuple_set(((
    e1,
    e2,
) for e1, e2 in relations_list),
                               name='relation_name');

destrieux_dataset = datasets.fetch_atlas_destrieux_2009()
destrieux_map = nib.load(destrieux_dataset['maps'])

destrieux = []
for label_number, name in destrieux_dataset['labels']:
    if label_number == 0:
        continue
    name = name.decode()
    region = RegionMixin.create_region(
        destrieux_map, label=label_number
    )
    if region is None:
        continue
    name = name.replace('-', '_').replace(' ', '_').lower()
    destrieux.append((name, region))

nl.add_tuple_set(((
    name,
    region,
) for name, region in destrieux), name='relation_region');

# %%
from operator import eq
from neurolang.logic import Implication
from nilearn import datasets
import nibabel as nib
from neurolang.frontend.query_resolution import RegionMixin
from neurolang.expressions import ExpressionBlock, Symbol, Constant
from neurolang.logic import Implication
from neurolang.datalog.aggregation import AggregationApplication

C_ = Constant

destrieux_name = Symbol('destrieux_name')
destrieux_region = Symbol('destrieux_region')
fma_name = Symbol('fma_name')
triple = Symbol('triple')
x = Symbol('x')
y = Symbol('y')
z = Symbol('z')
eq_ = Constant(eq)
id_ = Symbol('id_')
reg = Symbol('reg')
ans = Symbol('ans')
over = Symbol('over')
sub = Symbol('sub')
auditory = Symbol('auditory')
neurosynth = Symbol('neurosynth')
regional_part = Symbol('http://sig.biostr.washington.edu/fma3.0#regional_part_of')
label = Symbol('http://www.w3.org/2000/01/rdf-schema#label')
subClassOf = Symbol('http://www.w3.org/2000/01/rdf-schema#subClassOf')
region = Symbol('region')
overlapping = nl.symbols.overlapping.expression()
overlapping.args = (x,y)

@nl.add_symbol
def region_volume(region: fe.ExplicitVBR) -> float:
    volume = (
        len(region.voxels) *
        float(np.product(np.abs(np.linalg.eigvals(region.affine[:-1, :-1]))))
    )
    return volume  

@nl.add_symbol
def region_union(
    region_set: typing.AbstractSet[Region]
) -> Region:
    return region_union_(region_set)

@nl.add_symbol
def region_intersection(
    region_left: Region, region_right: Region
) -> Region:
    
    r_ijk = region_right.to_ijk(region_left.affine)
    region_right = ExplicitVBR(r_ijk, region_left.affine, image_dim=region_left.image_dim)
    temp = region_intersection_((region_left, region_right))
    if temp is None:
        return ExplicitVBR([[0,0,0]], region_left.affine)
    return temp


region_union = nl.symbols.region_union.expression()
region_union.args = (z,)

region_intersection = nl.symbols.region_intersection.expression()
region_intersection.args = (x, y)

agap = AggregationApplication(region_union.functor, (z,))

imps = tuple()

q = 0.0001
neurosynth_auditory = nl.load_neurosynth_term_regions(
    'auditory',
    name='neurosynth_auditory',
    q=q,
)

with nl.scope as e:
    e.regions_part[e.y, e.x] = (
        e.regional_part(e.y, e.x)
    )
    
    e.regions_part[e.y, e.x] = (
        e.regional_part(e.y, e.x) & e.regions_part(e.x, e.z)
    )
    
    ans = nl.query(
        (e.region_union(e.region),),
        e.label(e.id, 'Temporal lobe') & 
        e.regions_part(e.parts, e.id) &
        e.subClassOf(e.subClass, e.parts) &
        e.label(e.subClass, e.class_label) &
        e.relation_name(e.destrtieux_name, e.subClass) &
        e.relation_region(e.destrieux_region, e.destrieux_region) & 
        e.neurosynth_auditory(e.neurosynth_region) &
        (e.z == nl.symbols.overlapping(e.destrieux_region, e.neurosynth_region)) &
        (e.region == nl.symbols.region_intersection(e.z))   
    )


#Auditory
#imps += (Implication(id_(y), label(y, C_('Temporal lobe'))),)
#imps += (Implication(reg(y), regional_part(y, x) & id_(x)),)
#imps += (Implication(reg(y), regional_part(y, x) & reg(x)),)
#imps += (Implication(sub(y), subClassOf(y, x) & reg(x)),)
#imps += (Implication(region(y), sub(x) & label(x, y)),)
#imps += (Implication(destrieux_region(z), relation_region(z, x) & relation_name(x, y) & region(y)),)
#imps += (Implication(over(agap), neurosynth(C_('auditory'), y) & destrieux_region(x) & overlapping & eq_(z, region_intersection)),)
qB = ExpressionBlock(imps)

# %%
Implication(over(agap), neurosynth(C_('auditory'), y) & destrieux_region(x) & overlapping & eq_(z, region_intersection))
# Out:
# Implication{λ{S{over: Unknown}: Unknown}(λ{<C{region_union: typing.Callable[[typing.AbstractSet[neurolang.regions.Region]], neurolang.regions.Region]}>: Region}(S{z: Unknown})) ← λ{C{and_: typing.Callable[[neurolang.type_system.Unknown, bool], neurolang.type_system.Unknown]}: Unknown}(λ{C{and_: typing.Callable[[neurolang.type_system.Unknown, bool], neurolang.type_system.Unknown]}: Unknown}(λ{C{and_: typing.Callable[[neurolang.type_system.Unknown, neurolang.type_system.Unknown], neurolang.type_system.Unknown]}: Unknown}(λ{S{neurosynth: Unknown}: Unknown}(C{'auditory': str}, S{y: Unknown}), λ{S{destrieux_region: Unknown}: Unknown}(S{x: Unknown})), λ{C{RegionSolver.__new__.<locals>.build_function.<locals>.fun: typing.Callable[[neurolang.regions.Region, neurolang.regions.Region], bool]}: bool}(S{x: Unknown}, S{y: Unknown})), λ{C{eq: typing.Callable[[neurolang.type_system.Unknown, neurolang.type_system.Unknown], bool]}: bool}(S{z: Unknown}, λ{C{region_intersection: typing.Callable[[neurolang.regions.Region, neurolang.regions.Region], neurolang.regions.Region]}: Region}(S{x: Unknown}, S{y: Unknown})))}

# %%
orw = OntologyRewriter(qB, datalog_program.get_constraints())
rewrite = orw.Xrewrite()

# %%
from neurolang.datalog import DatalogProgram
from neurolang.datalog.expressions import TranslateToLogic
from neurolang import expression_walker as ew
from neurolang.regions import region_intersection as region_intersection_, ExplicitVBR
from neurolang.datalog.aggregation import DatalogWithAggregationMixin
    
triple = Symbol('triple')
class Datalog2(TranslateToLogic,
    DatalogWithAggregationMixin, DatalogProgram,
    ExpressionBasicEvaluator):
    pass
    
class DatalogTranslator(
    TranslateToLogic, ew.IdentityWalker, DatalogWithAggregationMixin
):
    pass

eB = ()
for imp in rewrite:
    eB += (imp[0],)
    
eB = ExpressionBlock(eB)

from neurolang.frontend.neurosynth_utils import NeuroSynthHandler

q = 0.00000001
nshandler = NeuroSynthHandler()
neurosynth_data = nshandler.ns_region_set_from_term(
    'auditory',
    q=q
)

dl2 = Datalog2()
dl2.add_extensional_predicate_from_tuples(triple, [(a.args[0].value, a.args[1].value, a.args[2].value) for a in onto.triples])
dl2.add_extensional_predicate_from_tuples(relation_region, [(a.args[0].value, a.args[1].value) for a in r_region])
dl2.add_extensional_predicate_from_tuples(relation_name, [(a.args[0].value, a.args[1].value) for a in r_name])
dl2.add_extensional_predicate_from_tuples(neurosynth, [('auditory', a) for a in neurosynth_data])

dt = DatalogTranslator()
eB2 = dt.walk(eB)
dl2.walk(eB2)
# Out:
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/neurosynth/base/dataset.py:435: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/gzanitti/Projects/INRIA/NeuroLang/neurolang/frontend/neurosynth_data/dataset.pkl'>
#   dataset = pickle.load(open(filename, 'rb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/neurosynth/base/dataset.py:716: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   feature_weights = self.data.ix[:, features]
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/pandas/core/indexing.py:888: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/neurosynth/base/mask.py:232: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
#   return self.volume.get_header()
# ∪(Implication{λ{S{reg: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://sig.biostr.washington.edu/fma3.0#regional_part_of': str}, S{x: Unknown}), λ{S{reg: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{sub: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{http://www.w3.org/2000/01/rdf-schema#subClassOf: Unknown}: Unknown}(S{y: Unknown}, S{x: Unknown}), λ{S{reg: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{over: Unknown}: Unknown}(λ{<C{region_union: typing.Callable[[typing.AbstractSet[neurolang.regions.Region]], neurolang.regions.Region]}>: Region}(S{z: Unknown})) ← ⋀(λ{S{neurosynth: Unknown}: Unknown}(C{'auditory': str}, S{y: Unknown}), λ{S{destrieux_region: Unknown}: Unknown}(S{x: Unknown}), λ{C{RegionSolver.__new__.<locals>.build_function.<locals>.fun: typing.Callable[[neurolang.regions.Region, neurolang.regions.Region], bool]}: bool}(S{x: Unknown}, S{y: Unknown}), λ{C{eq: typing.Callable[[neurolang.type_system.Unknown, neurolang.type_system.Unknown], bool]}: bool}(S{z: Unknown}, λ{C{region_intersection: typing.Callable[[neurolang.regions.Region, neurolang.regions.Region], neurolang.regions.Region]}: Region}(S{x: Unknown}, S{y: Unknown})))},
# Implication{λ{S{id_: Unknown}: Unknown}(S{y: Unknown}) ← λ{S{http://www.w3.org/2000/01/rdf-schema#label: Unknown}: Unknown}(S{y: Unknown}, C{'Temporal lobe': str})},
# Implication{λ{S{sub: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://www.w3.org/2000/01/rdf-schema#subClassOf': str}, S{x: Unknown}), λ{S{reg: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{reg: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://sig.biostr.washington.edu/fma3.0#regional_part_of': str}, S{x: Unknown}), λ{S{id_: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{reg: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{http://sig.biostr.washington.edu/fma3.0#regional_part_of: Unknown}: Unknown}(S{y: Unknown}, S{x: Unknown}), λ{S{reg: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{region: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{sub: Unknown}: Unknown}(S{x: Unknown}), λ{S{triple: Unknown}: Unknown}(S{x: Unknown}, C{'http://www.w3.org/2000/01/rdf-schema#label': str}, S{y: Unknown}))},
# Implication{λ{S{id_: Unknown}: Unknown}(S{y: Unknown}) ← λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://www.w3.org/2000/01/rdf-schema#label': str}, C{'Temporal lobe': str})},
# Implication{λ{S{reg: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{http://sig.biostr.washington.edu/fma3.0#regional_part_of: Unknown}: Unknown}(S{y: Unknown}, S{x: Unknown}), λ{S{id_: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{region: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{sub: Unknown}: Unknown}(S{x: Unknown}), λ{S{http://www.w3.org/2000/01/rdf-schema#label: Unknown}: Unknown}(S{x: Unknown}, S{y: Unknown}))},
# Implication{λ{S{destrieux_region: Unknown}: Unknown}(S{z: Unknown}) ← ⋀(λ{S{relation_region: Unknown}: Unknown}(S{z: Unknown}, S{x: Unknown}), λ{S{relation_name: Unknown}: Unknown}(S{x: Unknown}, S{y: Unknown}), λ{S{region: Unknown}: Unknown}(S{y: Unknown}))})

# %%
from neurolang.datalog.chase import ChaseSemiNaive, ChaseNaive, ChaseNamedRelationalAlgebraMixin, ChaseGeneral
from neurolang.datalog.aggregation import Chase

class Chase2(
    Chase, ChaseNaive, ChaseNamedRelationalAlgebraMixin, ChaseGeneral
):
    pass

dc = Chase2(dl2)
solution_instance = dc.build_chase_solution()
list(solution_instance.keys())
# Out:
# /Users/gzanitti/Projects/INRIA/NeuroLang/neurolang/datalog/aggregation.py:131: UserWarning: No check performed. Should implement check for stratified aggregation
#   "No check performed. Should implement check for stratified"
# [S{relation_region: typing.AbstractSet[typing.Tuple[neurolang.regions.ExplicitVBR, str]]},
#  S{relation_name: typing.AbstractSet[typing.Tuple[str, str]]},
#  S{neurosynth: typing.AbstractSet[typing.Tuple[str, neurolang.regions.ExplicitVBR]]},
#  S{triple: typing.AbstractSet[typing.Tuple[str, str, str]]},
#  S{id_: Unknown},
#  S{region: Unknown},
#  S{destrieux_region: Unknown},
#  S{reg: Unknown},
#  S{sub: Unknown},
#  S{over: Unknown}]

# %%
list(solution_instance['sub'].value.unwrapped_iter())
# Out:
# [('http://sig.biostr.washington.edu/fma3.0#Left_posterior_transverse_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_posterior_transverse_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Left_middle_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_middle_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Left_inferior_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_inferior_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_superior_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Left_superior_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Left_anterior_transverse_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_anterior_transverse_temporal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_fusiform_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Left_fusiform_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Left_parahippocampal_gyrus',),
#  ('http://sig.biostr.washington.edu/fma3.0#Right_parahippocampal_gyrus',)]

# %%
from nilearn import plotting

list_regions = list(solution_instance['over'].value.unwrapped_iter())
for region in list_regions:
    plotting.plot_roi(region[0].spatial_image(), title='Auditory')
# Out:
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/scipy/ndimage/measurements.py:305: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   return _nd_image.find_objects(input, max_label)

# %%
import pandas as pd
import rdflib

def _create_graph(paths, load_format='xml'):
        df = pd.DataFrame()
        temp = []
        for path in paths:
            g = rdflib.Graph()
            g.load(path, format=load_format)
            gdf = pd.DataFrame(iter(g))
            gdf = gdf.astype(str)
            gdf.columns = ['Entity', 'Property', 'Value']
            temp.append(gdf)

        return df.append(temp)

# %%
mesh = _create_graph(['./mesh2020.nt'], load_format='nt')

# %%
mesh[mesh.Value.str.contains('Auditory Processing Disorder')]
# Out:
#                                             Entity  \
# 3575883   http://id.nlm.nih.gov/mesh/2020/M0337628
# 8376760    http://id.nlm.nih.gov/mesh/2020/T373044
# 10108748   http://id.nlm.nih.gov/mesh/2020/T363964
# 13499803   http://id.nlm.nih.gov/mesh/2020/T363964
# 13591433   http://id.nlm.nih.gov/mesh/2020/T373045
#
#                                             Property  \
# 3575883   http://www.w3.org/2000/01/rdf-schema#label
# 8376760   http://id.nlm.nih.gov/mesh/vocab#prefLabel
# 10108748  http://id.nlm.nih.gov/mesh/vocab#prefLabel
# 13499803   http://id.nlm.nih.gov/mesh/vocab#altLabel
# 13591433  http://id.nlm.nih.gov/mesh/vocab#prefLabel
#
#                                           Value
# 3575883   Auditory Processing Disorder, Central
# 8376760   Auditory Processing Disorder, Central
# 10108748           Auditory Processing Disorder
# 13499803          Auditory Processing Disorders
# 13591433   Central Auditory Processing Disorder

# %%
temp = mesh[mesh.Value.str.endswith('http://id.nlm.nih.gov/mesh/2020/T363964')]
temp
# Out:
#                                            Entity  \
# 5256563  http://id.nlm.nih.gov/mesh/2020/M0001969
#
#                                       Property  \
# 5256563  http://id.nlm.nih.gov/mesh/vocab#term
#
#                                            Value
# 5256563  http://id.nlm.nih.gov/mesh/2020/T363964

# %%
temp2 = mesh[mesh.Entity.str.endswith('http://id.nlm.nih.gov/mesh/2020/M0001969')]
temp2
# Out:
#                                             Entity  \
# 766755    http://id.nlm.nih.gov/mesh/2020/M0001969
# 931075    http://id.nlm.nih.gov/mesh/2020/M0001969
# 5256563   http://id.nlm.nih.gov/mesh/2020/M0001969
# 5622180   http://id.nlm.nih.gov/mesh/2020/M0001969
# 5711626   http://id.nlm.nih.gov/mesh/2020/M0001969
# 6441294   http://id.nlm.nih.gov/mesh/2020/M0001969
# 7256301   http://id.nlm.nih.gov/mesh/2020/M0001969
# 10224282  http://id.nlm.nih.gov/mesh/2020/M0001969
# 10381434  http://id.nlm.nih.gov/mesh/2020/M0001969
# 12754469  http://id.nlm.nih.gov/mesh/2020/M0001969
# 12986595  http://id.nlm.nih.gov/mesh/2020/M0001969
#
#                                                   Property  \
# 766755     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 931075               http://id.nlm.nih.gov/mesh/vocab#term
# 5256563              http://id.nlm.nih.gov/mesh/vocab#term
# 5622180        http://id.nlm.nih.gov/mesh/vocab#identifier
# 5711626              http://id.nlm.nih.gov/mesh/vocab#term
# 6441294              http://id.nlm.nih.gov/mesh/vocab#term
# 7256301         http://id.nlm.nih.gov/mesh/vocab#scopeNote
# 10224282        http://www.w3.org/2000/01/rdf-schema#label
# 10381434             http://id.nlm.nih.gov/mesh/vocab#term
# 12754469  http://id.nlm.nih.gov/mesh/vocab#narrowerConcept
# 12986595    http://id.nlm.nih.gov/mesh/vocab#preferredTerm
#
#                                                       Value
# 766755             http://id.nlm.nih.gov/mesh/vocab#Concept
# 931075              http://id.nlm.nih.gov/mesh/2020/T363963
# 5256563             http://id.nlm.nih.gov/mesh/2020/T363964
# 5622180                                            M0001969
# 5711626             http://id.nlm.nih.gov/mesh/2020/T363962
# 6441294             http://id.nlm.nih.gov/mesh/2020/T363965
# 7256301   Acquired or developmental cognitive disorders ...
# 10224282                      Auditory Perceptual Disorders
# 10381434            http://id.nlm.nih.gov/mesh/2020/T363961
# 12754469           http://id.nlm.nih.gov/mesh/2020/M0332673
# 12986595            http://id.nlm.nih.gov/mesh/2020/T003881

# %%
temp2 = mesh[mesh.Value.str.endswith('http://id.nlm.nih.gov/mesh/2020/M0001969')]
temp2
# Out:
#                                           Entity  \
# 5110963  http://id.nlm.nih.gov/mesh/2020/D001308
#
#                                                   Property  \
# 5110963  http://id.nlm.nih.gov/mesh/vocab#preferredConcept
#
#                                             Value
# 5110963  http://id.nlm.nih.gov/mesh/2020/M0001969

# %%
temp2 = mesh[mesh.Entity.str.endswith('http://id.nlm.nih.gov/mesh/2020/D001308')]
temp2
# Out:
#                                            Entity  \
# 117179    http://id.nlm.nih.gov/mesh/2020/D001308
# 284537    http://id.nlm.nih.gov/mesh/2020/D001308
# 1117721   http://id.nlm.nih.gov/mesh/2020/D001308
# 1588494   http://id.nlm.nih.gov/mesh/2020/D001308
# 1634205   http://id.nlm.nih.gov/mesh/2020/D001308
# 1838612   http://id.nlm.nih.gov/mesh/2020/D001308
# 2182774   http://id.nlm.nih.gov/mesh/2020/D001308
# 2557973   http://id.nlm.nih.gov/mesh/2020/D001308
# 2860361   http://id.nlm.nih.gov/mesh/2020/D001308
# 2882948   http://id.nlm.nih.gov/mesh/2020/D001308
# 2894575   http://id.nlm.nih.gov/mesh/2020/D001308
# 2895995   http://id.nlm.nih.gov/mesh/2020/D001308
# 3639369   http://id.nlm.nih.gov/mesh/2020/D001308
# 3928823   http://id.nlm.nih.gov/mesh/2020/D001308
# 5110963   http://id.nlm.nih.gov/mesh/2020/D001308
# 5187440   http://id.nlm.nih.gov/mesh/2020/D001308
# 5247928   http://id.nlm.nih.gov/mesh/2020/D001308
# 6055777   http://id.nlm.nih.gov/mesh/2020/D001308
# 6084548   http://id.nlm.nih.gov/mesh/2020/D001308
# 6209514   http://id.nlm.nih.gov/mesh/2020/D001308
# 6227158   http://id.nlm.nih.gov/mesh/2020/D001308
# 6347973   http://id.nlm.nih.gov/mesh/2020/D001308
# 6429197   http://id.nlm.nih.gov/mesh/2020/D001308
# 6584780   http://id.nlm.nih.gov/mesh/2020/D001308
# 6755196   http://id.nlm.nih.gov/mesh/2020/D001308
://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 2648401      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 3788115      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 4134785      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 4538836      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 4577661      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 6178092   http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 6355870   http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 6596710      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 6987482      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 7367745      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 7416509      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 7893878      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 8223475      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 9069325      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 9920582      http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 10057620     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 10104700     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 10727565     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 11078272     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 11442542     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 12457002     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 12727654     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 12920333     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# 13404372  http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 13597736     http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
#
#                                             Value
# 1422500   http://id.nlm.nih.gov/mesh/2020/D013702
# 2648401   http://id.nlm.nih.gov/mesh/2020/D013702
# 3788115   http://id.nlm.nih.gov/mesh/2020/D013702
# 4134785   http://id.nlm.nih.gov/mesh/2020/D013702
# 4538836   http://id.nlm.nih.gov/mesh/2020/D013702
# 4577661   http://id.nlm.nih.gov/mesh/2020/D013702
# 6178092   http://id.nlm.nih.gov/mesh/2020/D013702
# 6355870   http://id.nlm.nih.gov/mesh/2020/D013702
# 6596710   http://id.nlm.nih.gov/mesh/2020/D013702
# 6987482   http://id.nlm.nih.gov/mesh/2020/D013702
# 7367745   http://id.nlm.nih.gov/mesh/2020/D013702
# 7416509   http://id.nlm.nih.gov/mesh/2020/D013702
# 7893878   http://id.nlm.nih.gov/mesh/2020/D013702
# 8223475   http://id.nlm.nih.gov/mesh/2020/D013702
# 9069325   http://id.nlm.nih.gov/mesh/2020/D013702
# 9920582   http://id.nlm.nih.gov/mesh/2020/D013702
# 10057620  http://id.nlm.nih.gov/mesh/2020/D013702
# 10104700  http://id.nlm.nih.gov/mesh/2020/D013702
# 10727565  http://id.nlm.nih.gov/mesh/2020/D013702
# 11078272  http://id.nlm.nih.gov/mesh/2020/D013702
# 11442542  http://id.nlm.nih.gov/mesh/2020/D013702
# 12457002  http://id.nlm.nih.gov/mesh/2020/D013702
# 12727654  http://id.nlm.nih.gov/mesh/2020/D013702
# 12920333  http://id.nlm.nih.gov/mesh/2020/D013702
# 13404372  http://id.nlm.nih.gov/mesh/2020/D013702
# 13597736  http://id.nlm.nih.gov/mesh/2020/D013702

# %%
#auditory cortex
temp = mesh[mesh.Entity.str.endswith('http://id.nlm.nih.gov/mesh/2020/D001303')]
# Out:
#                                            Entity  \
# 240152    http://id.nlm.nih.gov/mesh/2020/D001303
# 781461    http://id.nlm.nih.gov/mesh/2020/D001303
# 1112152   http://id.nlm.nih.gov/mesh/2020/D001303
# 1805209   http://id.nlm.nih.gov/mesh/2020/D001303
# 1815813   http://id.nlm.nih.gov/mesh/2020/D001303
# 2026099   http://id.nlm.nih.gov/mesh/2020/D001303
# 2287808   http://id.nlm.nih.gov/mesh/2020/D001303
http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 8774568            http://id.nlm.nih.gov/mesh/vocab#concept
# 8870030   http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 9043848   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 9226262            http://id.nlm.nih.gov/mesh/vocab#seeAlso
# 9243297   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 9510238   http://id.nlm.nih.gov/mesh/vocab#previousIndexing
# 10502610        http://id.nlm.nih.gov/mesh/vocab#treeNumber
# 10810757  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 10814917  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11006760         http://www.w3.org/2000/01/rdf-schema#label
# 11286495  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11293476  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11873783   http://id.nlm.nih.gov/mesh/vocab#dateEstablished
# 12371644  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 12622101  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 13198884    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 13404372  http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 13467969        http://id.nlm.nih.gov/mesh/vocab#treeNumber
# 13578017  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 13605237  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
#
#                                                       Value
# 240152              http://id.nlm.nih.gov/mesh/2020/Q000502
# 781461                                           1999-01-01
# 1112152             http://id.nlm.nih.gov/mesh/2020/Q000196
# 1805209             http://id.nlm.nih.gov/mesh/2020/Q000166
# 1815813             http://id.nlm.nih.gov/mesh/2020/Q000648
# 2026099                                              70(68)
# 2287808                         Cerebral Cortex (1966-1967)
# 2724825             http://id.nlm.nih.gov/mesh/2020/Q000473
# 2742366                                          2018-06-30
# 3079706             http://id.nlm.nih.gov/mesh/2020/Q000528
# 3308503             http://id.nlm.nih.gov/mesh/2020/Q000382
# 3315109             http://id.nlm.nih.gov/mesh/2020/Q000601
# 3395430             http://id.nlm.nih.gov/mesh/2020/Q000821
# 3664899             http://id.nlm.nih.gov/mesh/2020/Q000201
# 4552596                                             D001303
# 4794210                                                  70
# 5432541                                              WL 307
# 5535525          http://id.nlm.nih.gov/mesh/2020/Q000000981
# 5856740            http://id.nlm.nih.gov/mesh/2020/M0593014
# 6057937             http://id.nlm.nih.gov/mesh/2020/Q000293
# 6413849            http://id.nlm.nih.gov/mesh/2020/M0001963
# 7939997             http://id.nlm.nih.gov/mesh/2020/T003874
# 8134548   diseases: coordinate with AUDITORY DISEASES, C...
# 8606631             http://id.nlm.nih.gov/mesh/2020/Q000503
# 8774568            http://id.nlm.nih.gov/mesh/2020/M0593013
# 8870030             http://id.nlm.nih.gov/mesh/2020/D066191
# 9043848             http://id.nlm.nih.gov/mesh/2020/Q000637
# 9226262             http://id.nlm.nih.gov/mesh/2020/D001304
# 9243297             http://id.nlm.nih.gov/mesh/2020/Q000737
# 9510238                                 Hearing (1966-1967)
# 10502610  http://id.nlm.nih.gov/mesh/2020/A08.186.211.20...
# 10810757            http://id.nlm.nih.gov/mesh/2020/Q000469
# 10814917            http://id.nlm.nih.gov/mesh/2020/Q000098
# 11006760                                    Auditory Cortex
# 11286495            http://id.nlm.nih.gov/mesh/2020/Q000276
# 11293476            http://id.nlm.nih.gov/mesh/2020/Q000033
# 11873783                                         1970-01-01
# 12371644            http://id.nlm.nih.gov/mesh/2020/Q000378
# 12622101            http://id.nlm.nih.gov/mesh/2020/Q000002
# 13198884  http://id.nlm.nih.gov/mesh/vocab#TopicalDescri...
# 11945013  http://id.nlm.nih.gov/mesh/2020/D001304
# 11993946  http://id.nlm.nih.gov/mesh/2020/D001304
# 12125608  http://id.nlm.nih.gov/mesh/2020/D001304
# 12337071  http://id.nlm.nih.gov/mesh/2020/D001304
# 13006552  http://id.nlm.nih.gov/mesh/2020/D001304
# 13335572  http://id.nlm.nih.gov/mesh/2020/D001304
# 13437259  http://id.nlm.nih.gov/mesh/2020/D001304
# 13649830  http://id.nlm.nih.gov/mesh/2020/D001304
#
#                                                    Property  \
# 38743     http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 330938    http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 386796    http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 659050    http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 732005          http://id.nlm.nih.gov/mesh/vocab#treeNumber
# 978840         http://id.nlm.nih.gov/mesh/vocab#historyNote
# 1299218   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 2327775   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 2365492   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 2433450        http://id.nlm.nih.gov/mesh/vocab#dateCreated
# 2517711   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 2644261   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 2801192   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 2951747   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 3117482   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 3123155   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 3599963         http://id.nlm.nih.gov/mesh/vocab#treeNumber
# 3734596   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 3900605   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 3997262   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 4574137   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 5165081   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 5183745     http://id.nlm.nih.gov/mesh/vocab#publicMeSHNote
# 5322763   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 5362837    http://id.nlm.nih.gov/mesh/vocab#dateEstablished
# 6363993            http://id.nlm.nih.gov/mesh/vocab#concept
# 6492393   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 7274409   http://id.nlm.nih.gov/mesh/vocab#nlmClassifica...
# 7278921   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 7465509   http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 7746764   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 8290941   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 8702123   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 9465633   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 9720774          http://www.w3.org/2000/01/rdf-schema#label
# 9906912   http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 10017077  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 10606584  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11151560  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11195745    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 11370998  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11395958       http://id.nlm.nih.gov/mesh/vocab#dateRevised
# 11599516        http://id.nlm.nih.gov/mesh/vocab#identifier
# 11945013  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 11993946  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 12125608  http://id.nlm.nih.gov/mesh/vocab#preferredConcept
# 12337071  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 13006552  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
# 13335572  http://id.nlm.nih.gov/mesh/vocab#broaderDescri...
# 13437259     http://id.nlm.nih.gov/mesh/vocab#preferredTerm
# 13649830  http://id.nlm.nih.gov/mesh/vocab#allowableQual...
#
#                                                       Value
# 38743            http://id.nlm.nih.gov/mesh/2020/Q000000981
# 330938              http://id.nlm.nih.gov/mesh/2020/Q000378
# 386796              http://id.nlm.nih.gov/mesh/2020/Q000523
# 659050              http://id.nlm.nih.gov/mesh/2020/Q000208
# 732005      http://id.nlm.nih.gov/mesh/2020/C10.228.140.068
# 978840                                                 1980
# 1299218             http://id.nlm.nih.gov/mesh/2020/Q000134
# 2327775             http://id.nlm.nih.gov/mesh/2020/Q000401
# 2365492             http://id.nlm.nih.gov/mesh/2020/Q000201
# 2433450                                          1978-12-22
# 2517711             http://id.nlm.nih.gov/mesh/2020/Q000235
# 2644261             http://id.nlm.nih.gov/mesh/2020/Q000628
# 2801192             http://id.nlm.nih.gov/mesh/2020/Q000503
# 2951747             http://id.nlm.nih.gov/mesh/2020/Q000662
# 3117482             http://id.nlm.nih.gov/mesh/2020/Q000145
# 3123155             http://id.nlm.nih.gov/mesh/2020/Q000266
# 3599963     http://id.nlm.nih.gov/mesh/2020/C09.218.807.186
# 3734596             http://id.nlm.nih.gov/mesh/2020/Q000097
# 3900605             http://id.nlm.nih.gov/mesh/2020/Q000517
# 3997262             http://id.nlm.nih.gov/mesh/2020/Q000382
# 4574137             http://id.nlm.nih.gov/mesh/2020/Q000209
# 5165081             http://id.nlm.nih.gov/mesh/2020/Q000175
# 5183745                                                1980
# 5322763             http://id.nlm.nih.gov/mesh/2020/Q000276
# 5362837                                          1980-01-01
# 6363993            http://id.nlm.nih.gov/mesh/2020/M0332667
# 6492393             http://id.nlm.nih.gov/mesh/2020/Q000469
# 7274409                                              WV 270
# 7278921             http://id.nlm.nih.gov/mesh/2020/Q000191
# 7465509             http://id.nlm.nih.gov/mesh/2020/D001927
# 7746764             http://id.nlm.nih.gov/mesh/2020/Q000601
# 8290941             http://id.nlm.nih.gov/mesh/2020/Q000532
# 8702123             http://id.nlm.nih.gov/mesh/2020/Q000453
# 9465633             http://id.nlm.nih.gov/mesh/2020/Q000196
# 9720774                          Auditory Diseases, Central
# 9906912             http://id.nlm.nih.gov/mesh/2020/Q000151
# 10017077            http://id.nlm.nih.gov/mesh/2020/Q000178
# 10606584            http://id.nlm.nih.gov/mesh/2020/Q000451
# 11151560            http://id.nlm.nih.gov/mesh/2020/Q000652
# 11195745  http://id.nlm.nih.gov/mesh/vocab#TopicalDescri...
# 11370998            http://id.nlm.nih.gov/mesh/2020/Q000188
# 11395958                                         2007-07-09
# 11599516                                            D001304
# 11945013            http://id.nlm.nih.gov/mesh/2020/Q000150
# 11993946            http://id.nlm.nih.gov/mesh/2020/Q000534
# 12125608           http://id.nlm.nih.gov/mesh/2020/M0001964
# 12337071            http://id.nlm.nih.gov/mesh/2020/Q000473
# 13006552            http://id.nlm.nih.gov/mesh/2020/Q000821
# 13335572            http://id.nlm.nih.gov/mesh/2020/D012181
# 13437259            http://id.nlm.nih.gov/mesh/2020/T003875
# 13649830            http://id.nlm.nih.gov/mesh/2020/Q000139

# %%
mesh[mesh.Value.str.endswith('http://id.nlm.nih.gov/mesh/2020/D001304')].Property.unique()
# Out:
# array(['http://id.nlm.nih.gov/mesh/vocab#hasDescriptor',
#        'http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor',
#        'http://id.nlm.nih.gov/mesh/vocab#seeAlso'], dtype=object)

# %% [markdown]
# Auditory Processing Disorder -> label -> http://id.nlm.nih.gov/mesh/2020/T363964
# http://id.nlm.nih.gov/mesh/2020/M0001969 (Auditory Perceptual Disorders) -> termo-> http://id.nlm.nih.gov/mesh/2020/T363964
# "" -> preferedConcept -> http://id.nlm.nih.gov/mesh/2020/D001308
# #http://id.nlm.nih.gov/mesh/D001308 -> seeAlso -> http://id.nlm.nih.gov/mesh/2020/D001307

# %%
from neurolang.datalog.ontologies_parser import OntologiesParser
from neurolang.datalog.ontologies_rewriter import OntologyRewriter

from neurolang.datalog.constraints_representation import DatalogConstraintsProgram
from neurolang.expression_walker import ExpressionBasicEvaluator

from neurolang import frontend as fe

class Datalog(DatalogConstraintsProgram, ExpressionBasicEvaluator):
    pass

paths = ['./mesh2020.nt']
namespaces = ['http://id.nlm.nih.gov/mesh/']
onto = OntologiesParser(paths, namespaces, load_format='nt')
dl = Datalog()
nl = fe.NeurolangDL()
datalog_program = onto.parse_ontology(nl.solver)
# Out:
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/gzanitti/Projects/INRIA/NeuroLang/neurolang/utils/data_manipulation.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from operator import eq
from neurolang.logic import Implication
from nilearn import datasets
import nibabel as nib
from neurolang.frontend.query_resolution import RegionMixin
from neurolang.expressions import ExpressionBlock, Symbol, Constant
from neurolang.logic import Implication

C_ = Constant

destrieux_name = Symbol('destrieux_name')
destrieux_region = Symbol('destrieux_region')
fma_name = Symbol('fma_name')
triple = Symbol('triple')
x = Symbol('x')
y = Symbol('y')
z = Symbol('z')
eq_ = Constant(eq)
id_ = Symbol('id_')
reg = Symbol('reg')
ans = Symbol('ans')
over = Symbol('over')
sub = Symbol('sub')
auditory = Symbol('auditory')
neurosynth_auditory = Symbol('neurosynth_auditory')
regional_part = Symbol('http://sig.biostr.washington.edu/fma3.0#regional_part_of')
label = Symbol('http://www.w3.org/2000/01/rdf-schema#label')
subClassOf = Symbol('http://www.w3.org/2000/01/rdf-schema#subClassOf')
seeAlso = Symbol('http://id.nlm.nih.gov/mesh/vocab#seeAlso')
broaderDescriptor = Symbol('http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor')
region = Symbol('region')
overlapping = nl.symbols.overlapping.expression()
overlapping.args = (x,y)

@nl.add_symbol
def region_volume(region: fe.ExplicitVBR) -> float:
    volume = (
        len(region.voxels) *
        float(np.product(np.abs(np.linalg.eigvals(region.affine[:-1, :-1]))))
    )
    return volume  

@nl.add_symbol
def region_union(
    region_set: typing.AbstractSet[Region]
) -> Region:
    return region_union_(region_set)

region_union = nl.symbols.region_union.expression()
region_union.args = (x,)

imps = tuple()


#Auditory
imps += (Implication(id_(y), label(y, C_('Auditory Perceptual Disorders'))),)
imps += (Implication(reg(x), broaderDescriptor(y, x) & id_(y)),)
imps += (Implication(region(y), seeAlso(y, x) & reg(x)),)
imps += (Implication(sub(x), broaderDescriptor(y, x) & region(y)),)
imps += (Implication(ans(y), sub(x) & label(x, y)),)

qB = ExpressionBlock(imps)

# %%
orw = OntologyRewriter(qB, datalog_program.get_constraints())
rewrite = orw.Xrewrite()

# %%
from neurolang.datalog import DatalogProgram
from neurolang.datalog.expressions import TranslateToLogic
from neurolang import expression_walker as ew
    
triple = Symbol('triple')
class Datalog2(DatalogProgram, ExpressionBasicEvaluator):
    pass
    
class DatalogTranslator(
    TranslateToLogic, ew.IdentityWalker
):
    pass



#from neurolang.frontend.neurosynth_utils import NeuroSynthHandler

#q = 0.0001
#nshandler = NeuroSynthHandler()
#neurosynth_data = nshandler.ns_region_set_from_term(
#    'auditory',
#    q=q
#)

dl2 = Datalog2()
dl2.add_extensional_predicate_from_tuples(triple, [(a.args[0].value, a.args[1].value, a.args[2].value) for a in onto.triples])
#dl2.add_extensional_predicate_from_tuples(relation_region, [(a.args[0].value, a.args[1].value) for a in r_region])
#dl2.add_extensional_predicate_from_tuples(relation_name, [(a.args[0].value, a.args[1].value) for a in r_name])
#dl2.add_extensional_predicate_from_tuples(neurosynth_auditory, [(a,) for a in neurosynth_data])

# %%
eB = ()
for imp in rewrite:
    eB += (imp[0],)
    
eB = ExpressionBlock(eB)

dt = DatalogTranslator()
eB2 = dt.walk(eB)
dl2.walk(eB2)
# Out:
# ∪(Implication{λ{S{sub: Unknown}: Unknown}(S{x: Unknown}) ← ⋀(λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor': str}, S{x: Unknown}), λ{S{region: Unknown}: Unknown}(S{y: Unknown}))},
# Implication{λ{S{sub: Unknown}: Unknown}(S{x: Unknown}) ← ⋀(λ{S{http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor: Unknown}: Unknown}(S{y: Unknown}, S{x: Unknown}), λ{S{region: Unknown}: Unknown}(S{y: Unknown}))},
# Implication{λ{S{region: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://id.nlm.nih.gov/mesh/vocab#seeAlso': str}, S{x: Unknown}), λ{S{reg: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{id_: Unknown}: Unknown}(S{y: Unknown}) ← λ{S{http://www.w3.org/2000/01/rdf-schema#label: Unknown}: Unknown}(S{y: Unknown}, C{'Auditory Perceptual Disorders': str})},
# Implication{λ{S{ans: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{sub: Unknown}: Unknown}(S{x: Unknown}), λ{S{triple: Unknown}: Unknown}(S{x: Unknown}, C{'http://www.w3.org/2000/01/rdf-schema#label': str}, S{y: Unknown}))},
# Implication{λ{S{ans: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{sub: Unknown}: Unknown}(S{x: Unknown}), λ{S{http://www.w3.org/2000/01/rdf-schema#label: Unknown}: Unknown}(S{x: Unknown}, S{y: Unknown}))},
# Implication{λ{S{region: Unknown}: Unknown}(S{y: Unknown}) ← ⋀(λ{S{http://id.nlm.nih.gov/mesh/vocab#seeAlso: Unknown}: Unknown}(S{y: Unknown}, S{x: Unknown}), λ{S{reg: Unknown}: Unknown}(S{x: Unknown}))},
# Implication{λ{S{reg: Unknown}: Unknown}(S{x: Unknown}) ← ⋀(λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor': str}, S{x: Unknown}), λ{S{id_: Unknown}: Unknown}(S{y: Unknown}))},
# Implication{λ{S{id_: Unknown}: Unknown}(S{y: Unknown}) ← λ{S{triple: Unknown}: Unknown}(S{y: Unknown}, C{'http://www.w3.org/2000/01/rdf-schema#label': str}, C{'Auditory Perceptual Disorders': str})},
# Implication{λ{S{reg: Unknown}: Unknown}(S{x: Unknown}) ← ⋀(λ{S{http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor: Unknown}: Unknown}(S{y: Unknown}, S{x: Unknown}), λ{S{id_: Unknown}: Unknown}(S{y: Unknown}))})

# %%
from neurolang.datalog.chase import ChaseSemiNaive, ChaseNaive, ChaseNamedRelationalAlgebraMixin, ChaseGeneral

class Chase(
    ChaseNaive, ChaseNamedRelationalAlgebraMixin, ChaseGeneral
):
    pass

dc = Chase(dl2)
solution_instance = dc.build_chase_solution()
list(solution_instance.keys())
# Out:
# [S{triple: typing.AbstractSet[typing.Tuple[str, str, str]]},
#  S{id_: Unknown},
#  S{reg: Unknown},
#  S{region: Unknown},
#  S{sub: Unknown},
#  S{ans: Unknown}]

# %%
solution_instance['ans']
# Out:
# C{                     0
# 0                Aging
# 1           Perception
# 2  Sensorimotor Cortex
# 3        Temporal Lobe
# 4    Afferent Pathways: typing.AbstractSet[typing.Tuple[str]]}

# %%
q = 0.01
neurosynth_auditory = nl.load_neurosynth_term_regions(
    'auditory cortex',
    name='neurosynth_auditory',
    q=q,
)
# Out:
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/neurosynth/base/dataset.py:435: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/gzanitti/Projects/INRIA/NeuroLang/neurolang/frontend/neurosynth_data/dataset.pkl'>
#   dataset = pickle.load(open(filename, 'rb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/neurosynth/base/dataset.py:716: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   feature_weights = self.data.ix[:, features]
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/pandas/core/indexing.py:888: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
# /Users/gzanitti/miniconda3/envs/neurolang/lib/python3.7/site-packages/neurosynth/base/mask.py:232: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
#   return self.volume.get_header()

# %%
with nl.scope as e:
    e.temporal_union[region_union(e.region)] = (
        e.neurosynth_auditory(e.region) &
        (e.region_volume(e.region) > 0)
    )
    
    res2 = nl.query(
        (e.region,),
        e.temporal_union(e.region)
    )
        
    for region in res2:
        plotting.plot_roi(region[0].spatial_image(), title='Auditory')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-528e161ea841> in <module>
#       2     e.temporal_union[region_union(e.region)] = (
#       3         e.neurosynth_auditory(e.region) &
# ----> 4         (e.region_volume(e.region) > 0)
#       5     )
#       6
#
# ~/Projects/INRIA/NeuroLang/neurolang/expressions.py in __call__(self, *args, **kwargs)
#     239
#     240         return FunctionApplication[variable_type](
# --> 241             self, args, kwargs,
#     242          )
#     243
#
# ~/Projects/INRIA/NeuroLang/neurolang/expressions.py in new_init(self, *args, **kwargs)
#     205                 init_process_pattern(self, args)
#     206             else:
# --> 207                 return orig_init(self, *args, **kwargs)
#     208
#     209         obj.__init__ = new_init
#
# ~/Projects/INRIA/NeuroLang/neurolang/expressions.py in new_init(self, *args, **kwargs)
#     205                 init_process_pattern(self, args)
#     206             else:
# --> 207                 return orig_init(self, *args, **kwargs)
#     208
#     209         obj.__init__ = new_init
#
# ~/Projects/INRIA/NeuroLang/neurolang/expressions.py in __init__(self, functor, args, kwargs)
#     568                 pass
#     569             elif isinstance(self.functor.type, typing.Callable):
# --> 570                 self.type = self.functor.type.__args__[-1]
#     571             else:
#     572                 raise NeuroLangTypeException("Functor is not an expression")
#
# AttributeError: type object 'Region' has no attribute '__args__'
